# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
total=1000

# %%
x=np.random.uniform(-200,200,total)
y=np.random.uniform(-400,400,total)
z=np.random.uniform(-100,100,total)
print(x[:3])
# Out:
# [-50.18395246 180.28572256  92.79757672]

# %%
points=[]
for i in range(total):
    points.append({"x":float(x[i]),
                   "y":float(y[i]),
                   "z":float(z[i])})

# %%
print(points[:4])
# Out:
# [{'x': -50.183952461055014, 'y': -251.89365692910428, 'z': -47.658863252818804}, {'x': 180.2857225639665, 'y': 33.52075790268651, 'z': -50.604240185600034}, {'x': 92.79757672456202, 'y': 298.35666870112664, 'z': 81.25091610420733}, {'x': 39.46339367881464, 'y': 185.77990912764892, 'z': -50.09076003009878}]

# %%
with open("dat.json","w")as file:
    data=json.dump(points,file,indent=4)
print(f"{total} data generated successsfully")
# Out:
# 1000 data generated successsfully

# %%
x=2,
y=3,
z=4

# %%
plot=plt.axes(projection='3d')
